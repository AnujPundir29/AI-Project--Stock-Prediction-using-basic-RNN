# %% [markdown]
# <a href="https://colab.research.google.com/github/AnujPundir29/AI-Project--Stock-Prediction-using-basic-RNN/blob/master/AI_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf


# Importing the training set
dataset_train = pd.read_csv('/content/Google_Stock_Price_Train.csv')
training_set = dataset_train.iloc[:, 1:2].values

# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# Creating a data structure with 60 timesteps and 1 output
X_train = []
y_train = []
for i in range(60, 1258):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# Reshaping
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))



# Building the RNN

# Initialising the RNN
regressor = tf.keras.models.Sequential()

# Adding the first LSTM layer and some Dropout regularisation
regressor.add(tf.keras.layers.LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(tf.keras.layers.Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
regressor.add(tf.keras.layers.LSTM(units = 50, return_sequences = True))
regressor.add(tf.keras.layers.Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
regressor.add(tf.keras.layers.LSTM(units = 50, return_sequences = True))
regressor.add(tf.keras.layers.Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
regressor.add(tf.keras.layers.LSTM(units = 50))
regressor.add(tf.keras.layers.Dropout(0.2))

# Adding the output layer
regressor.add(tf.keras.layers.Dense(units = 1))

# Compiling the RNN
regressor.compile(optimizer = 'adam', loss = 'mse',metrics=['accuracy'])

# Fitting the RNN to the Training set
regressor.fit(X_train, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 4s 111ms/step - loss: 0.0363 - accuracy: 0.0017
# Epoch 2/100
# 38/38 [==============================] - 4s 112ms/step - loss: 0.0064 - accuracy: 0.0017
# Epoch 3/100
# 38/38 [==============================] - 4s 112ms/step - loss: 0.0061 - accuracy: 0.0017
# Epoch 4/100
# 38/38 [==============================] - 4s 113ms/step - loss: 0.0050 - accuracy: 0.0017
# Epoch 5/100
# 38/38 [==============================] - 4s 113ms/step - loss: 0.0048 - accuracy: 0.0017
# Epoch 6/100
# 38/38 [==============================] - 4s 113ms/step - loss: 0.0056 - accuracy: 0.0017
# Epoch 7/100
# 38/38 [==============================] - 4s 113ms/step - loss: 0.0044 - accuracy: 0.0017
# Epoch 8/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0042 - accuracy: 0.0017
# Epoch 9/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0041 - accuracy: 0.0017
# Epoch 10/100
# 38/38 [==============================] - 5s 121ms/step - loss: 0.0044 - accuracy: 0.0017
# Epoch 11/100
# 38/38 [==============================] - 5s 121ms/step - loss: 0.0038 - accuracy: 0.0017
# Epoch 12/100
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0038 - accuracy: 0.0017
# Epoch 13/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0036 - accuracy: 0.0017
# Epoch 14/100
# 38/38 [==============================] - 4s 115ms/step - loss: 0.0034 - accuracy: 0.0017
# Epoch 15/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0041 - accuracy: 0.0017
# Epoch 16/100
# 38/38 [==============================] - 5s 128ms/step - loss: 0.0036 - accuracy: 0.0017
# Epoch 17/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0040 - accuracy: 0.0017
# Epoch 18/100
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0036 - accuracy: 0.0017
# Epoch 19/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0036 - accuracy: 0.0017
# Epoch 20/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0035 - accuracy: 0.0017
# Epoch 21/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0034 - accuracy: 0.0017
# Epoch 22/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0035 - accuracy: 0.0017
# Epoch 23/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0037 - accuracy: 0.0017
# Epoch 24/100
# 38/38 [==============================] - 4s 115ms/step - loss: 0.0034 - accuracy: 0.0017
# Epoch 25/100
# 38/38 [==============================] - 4s 115ms/step - loss: 0.0036 - accuracy: 0.0017
# Epoch 26/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0032 - accuracy: 0.0017
# Epoch 27/100
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0034 - accuracy: 0.0017
# Epoch 28/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0029 - accuracy: 0.0017
# Epoch 29/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0031 - accuracy: 0.0017
# Epoch 30/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0028 - accuracy: 0.0017
# Epoch 31/100
# 38/38 [==============================] - 4s 115ms/step - loss: 0.0033 - accuracy: 0.0017
# Epoch 32/100
# 38/38 [==============================] - 4s 115ms/step - loss: 0.0032 - accuracy: 0.0017
# Epoch 33/100
# 38/38 [==============================] - 5s 119ms/step - loss: 0.0026 - accuracy: 0.0017
# Epoch 34/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0029 - accuracy: 0.0017
# Epoch 35/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0026 - accuracy: 0.0017
# Epoch 36/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0025 - accuracy: 0.0017
# Epoch 37/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0029 - accuracy: 0.0017
# Epoch 38/100
# 38/38 [==============================] - 4s 115ms/step - loss: 0.0026 - accuracy: 0.0017
# Epoch 39/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0026 - accuracy: 0.0017
# Epoch 40/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0026 - accuracy: 0.0017
# Epoch 41/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0028 - accuracy: 0.0017
# Epoch 42/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0032 - accuracy: 0.0017
# Epoch 43/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0027 - accuracy: 0.0017
# Epoch 44/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0026 - accuracy: 0.0017
# Epoch 45/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0023 - accuracy: 0.0017
# Epoch 46/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0023 - accuracy: 0.0017
# Epoch 47/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0026 - accuracy: 0.0017
# Epoch 48/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0025 - accuracy: 0.0017
# Epoch 49/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0024 - accuracy: 0.0017
# Epoch 50/100
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0024 - accuracy: 0.0017
# Epoch 51/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0024 - accuracy: 0.0017
# Epoch 52/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0024 - accuracy: 0.0017
# Epoch 53/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0026 - accuracy: 0.0017
# Epoch 54/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0023 - accuracy: 0.0017
# Epoch 55/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0024 - accuracy: 0.0017
# Epoch 56/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0022 - accuracy: 0.0017
# Epoch 57/100
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0024 - accuracy: 0.0017
# Epoch 58/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0021 - accuracy: 0.0017
# Epoch 59/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0021 - accuracy: 0.0017
# Epoch 60/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0020 - accuracy: 0.0017
# Epoch 61/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0020 - accuracy: 0.0017
# Epoch 62/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0021 - accuracy: 0.0017
# Epoch 63/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0020 - accuracy: 0.0017
# Epoch 64/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0022 - accuracy: 0.0017
# Epoch 65/100
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0022 - accuracy: 0.0017
# Epoch 66/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0018 - accuracy: 0.0017
# Epoch 67/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0019 - accuracy: 0.0017
# Epoch 68/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0019 - accuracy: 0.0017
# Epoch 69/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0019 - accuracy: 0.0017
# Epoch 70/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0019 - accuracy: 0.0017
# Epoch 71/100
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0016 - accuracy: 0.0017
# Epoch 72/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0018 - accuracy: 0.0017
# Epoch 73/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0018 - accuracy: 0.0017
# Epoch 74/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0018 - accuracy: 0.0017
# Epoch 75/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0018 - accuracy: 0.0017
# Epoch 76/100
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0017 - accuracy: 0.0017
# Epoch 77/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0017 - accuracy: 0.0017
# Epoch 78/100
# 38/38 [==============================] - 5s 121ms/step - loss: 0.0017 - accuracy: 0.0017
# Epoch 79/100
# 38/38 [==============================] - 5s 122ms/step - loss: 0.0018 - accuracy: 0.0017
# Epoch 80/100
# 38/38 [==============================] - 5s 119ms/step - loss: 0.0015 - accuracy: 0.0017
# Epoch 81/100
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0018 - accuracy: 0.0017
# Epoch 82/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0018 - accuracy: 0.0017
# Epoch 83/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0019 - accuracy: 0.0017
# Epoch 84/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0020 - accuracy: 0.0017
# Epoch 85/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0016 - accuracy: 0.0017
# Epoch 86/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0016 - accuracy: 0.0017
# Epoch 87/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0017 - accuracy: 0.0017
# Epoch 88/100
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0016 - accuracy: 0.0017
# Epoch 89/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0017 - accuracy: 0.0017
# Epoch 90/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0016 - accuracy: 0.0017
# Epoch 91/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0015 - accuracy: 0.0017
# Epoch 92/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0016 - accuracy: 0.0017
# Epoch 93/100
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0014 - accuracy: 0.0017
# Epoch 94/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0014 - accuracy: 0.0017
# Epoch 95/100
# 38/38 [==============================] - 4s 118ms/step - loss: 0.0015 - accuracy: 0.0017
# Epoch 96/100
# 38/38 [==============================] - 4s 116ms/step - loss: 0.0015 - accuracy: 0.0017
# Epoch 97/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0014 - accuracy: 0.0017
# Epoch 98/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0014 - accuracy: 0.0017
# Epoch 99/100
# 38/38 [==============================] - 4s 117ms/step - loss: 0.0015 - accuracy: 0.0017
# Epoch 100/100
# 38/38 [==============================] - 5s 120ms/step - loss: 0.0014 - accuracy: 0.0017

# %%
dataset_test = pd.read_csv('/content/Google_Stock_Price_Test.csv')
real_stock_price = dataset_test.iloc[:, 1:2].values

# Getting the predicted stock price of 2017
dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 80):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# Visualising the results
plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
